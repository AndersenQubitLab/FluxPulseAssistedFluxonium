# %% [markdown]
# # Imports and initialization

# %%
# %matplotlib inline
import SQGfunctions as fn
from SQGfunctions import *

# %% [markdown]
# ## Initialize collapse operators and get drive frequency

# %%
#collapse operators
c_op1 = []
c_op2 = []

#energies and sweet spot defined in SQGfunctions.py file
H_sys,evals,evecs = fluxonium_system(sweet_spot,Ej,Ec,El,n_op,phi_op,H_lc,H_i)
Es = np.real(qubit_energies(H_sys,evals,evecs))
omega_drive = (Es[2]-Es[0])
drive_freq = omega_drive #define drive frequency

# %% [markdown]
# # Optimization

# %% [markdown]
# ## Loop over gate time

# %%
fids = []
errors = []
lambdas = [] #DRAG scaling factor
Eds = [] #drive amplitude

bnds = ((-3, 3), (0, 2)) #bounds, upper bound for drive amplitude estimated from analytic calculation
x_start = [0.5,1.5]
sigma_start = 0.5

times = np.linspace(10,50,41)
for t in times:
    optfunc = lambda x: 1-gate_pulse_no_fp(x[0],x[1],gatetime=t,drivefrequency=drive_freq,psi=initRho)[0]
    opts = cma.CMAOptions()
    #bounds for drive strength estimated from analytic calculation
    if t <= 20:
        x_start = [0.5, 1.5]
        bnds = ((-3, 3), (0, 2))
        opts.set("bounds", [(bnds[0][0], bnds[1][0]),(bnds[0][1], bnds[1][1])])
    elif t <= 30:
        x_start = [0.5, 0.75]
        bnds = ((-3, 3), (0, 1))
        opts.set("bounds", [(bnds[0][0], bnds[1][0]),(bnds[0][1], bnds[1][1])])
    elif t <= 40:
        x_start = [0.5, 0.5]
        bnds = ((-3, 3), (0, 0.7))
        opts.set("bounds", [(bnds[0][0], bnds[1][0]),(bnds[0][1], bnds[1][1])])
    else:
        x_start = [0.5, 0.25]
        bnds = ((-3, 3), (0, 0.5))
        opts.set("bounds", [(bnds[0][0], bnds[1][0]),(bnds[0][1], bnds[1][1])]) 
    opts.set('maxfevals', 1000)
    result = cma.fmin(optfunc, x0=x_start, sigma0=sigma_start, options=opts)
    result_best = vars(result[-2].best)
    values = result_best.get('x')
    error = result_best.get('f')
    errors.append(error)
    fids.append(1-error)
    lambdas.append(values[0])
    Eds.append(values[1])
# Out:
# (3_w,6)-aCMA-ES (mu_w=2.0,w_1=63%) in dimension 2 (seed=715445, Mon Sep 25 14:11:33 2023)
#
# lambda 0.16170293481233589
# drive 1.9442114325777153
# fidelity 0.8508025832414418
#
# lambda 0.6895496799707547
# drive 1.8417517645718051
# fidelity 0.9177265640092325
#
# lambda 0.18957614955898172
# drive 1.9998014465575704
# fidelity 0.8094238540307296
#
# lambda -0.43014637165058156
# drive 1.3080919164372327
# fidelity 0.9342656160005883
#
# lambda 0.5966219306721756
# drive 1.9151087652455818
# fidelity 0.8728610417589379
#
# lambda -0.28756579522033643
# drive 0.9465585543131156
# fidelity 0.6650041096259374
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1      6 6.573438399941167e-02 1.0e+00 5.17e-01  5e-01  6e-01 0:00.7
#
# lambda 0.6839936986716942
# drive 1.1279046453830086
# fidelity 0.8229643461806075
#
# lambda -0.42823064042221004
# drive 1.9934962333617434
# fidelity 0.8104898600963181
#
# lambda 0.5583681232981467
# drive 1.6645122870554099
# fidelity 0.9857291019721602
#
# lambda -0.05561759328956162
# drive 1.233694184194364
# fidelity 0.8947483882236074
#
# lambda 1.1465016717833834
# drive 1.5732775731119824
# fidelity 0.9986981890979768
#
# lambda -0.09674790722340762
# drive 0.6846403645565274
7
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 32
#      30     opts.set("bounds", [(bnds[0][0], bnds[1][0]),(bnds[0][1], bnds[1][1])])
#      31 opts.set('maxfevals', 1000)
# ---> 32 result = cma.fmin(optfunc, x0=x_start, sigma0=sigma_start, options=opts)
#      33 result_best = vars(result[-2].best)
#      34 values = result_best.get('x')
#
# File C:\Programs\Anaconda3\lib\site-packages\cma\evolution_strategy.py:4818, in fmin(objective_function, x0, sigma0, options, args, gradf, restarts, restart_from_best, incpopsize, eval_initial_x, parallel_objective, noise_handler, noise_change_sigma_exponent, noise_kappa_exponent, bipop, callback)
#    4815 if 1 < 3:
#    4816     while not es.stop():  # iteration loop
#    4817         # X, fit = eval_in_parallel(lambda: es.ask(1)[0], es.popsize, args, repetitions=noisehandler.evaluations-1)
# -> 4818         X, fit = es.ask_and_eval(parallel_objective or objective_function,
#    4819                                  args, gradf=gradf,
#    4820                                  evaluations=noisehandler.evaluations,
#    4821                                  aggregation=np.median,
#    4822                                  parallel_mode=parallel_objective)  # treats NaN with resampling if not parallel_mode
#    4823         # TODO: check args and in case use args=(noisehandler.evaluations, )
#    4825         if 11 < 3 and opts['vv']:  # inject a solution
#    4826             # use option check_point = [0]
#
# File C:\Programs\Anaconda3\lib\site-packages\cma\evolution_strategy.py:2528, in CMAEvolutionStrategy.ask_and_eval(self, func, args, gradf, number, xmean, sigma_fac, evaluations, aggregation, kappa, parallel_mode)
#    2524     length_normalizer = self.N**0.5 / self.mahalanobis_norm(x - xmean)  # self.const.chiN < N**0.5, the constant here is irrelevant (absorbed by kappa)
#    2525     # print(self.N**0.5 / self.mahalanobis_norm(x - xmean))
#    2526     # self.more_to_write += [length_normalizer * 1e-3, length_normalizer * self.mahalanobis_norm(x - xmean) * 1e2]
# -> 2528 f = func(x, *args) if kappa == 1 else \
#    2529     func(xmean + kappa * length_normalizer * (x - xmean),
#    2530          *args)
#    2531 if is_feasible(x, f) and evaluations > 1:
#    2532     f = aggregation([f] + [(func(x, *args) if kappa == 1 else
#    2533                             func(xmean + kappa * length_normalizer * (x - xmean), *args))
#    2534                            for _i in range(int(evaluations - 1))])
#
# Cell In[4], line 12, in <lambda>(x)
#      10 times = np.linspace(10,50,41)
#      11 for t in times:
# ---> 12     optfunc = lambda x: 1-gate_pulse_no_fp(x[0],x[1],gatetime=t,drivefrequency=drive_freq,psi=initRho)[0]
#      13     opts = cma.CMAOptions()
#      14     #bounds for drive strength estimated from analytic calculation
#
# File H:\taryn-phd\Cleaned\SingleQubitGates\SQGfunctions.py:220, in gate_pulse_no_fp(lamb, Ed, gatetime, drivefrequency, psi)
#     218 def gate_pulse_no_fp(lamb,Ed,gatetime,drivefrequency,psi):
#     219     time = np.linspace(0, gatetime, 101)
# --> 220     H_sys,evals,evecs = fluxonium_system(sweet_spot,Ej,Ec,El,n_op,phi_op,H_lc,H_i)
#     221     Es = np.real(qubit_energies(H_sys,evals,evecs))
#     222     alpha = (Es[4] - Es[2]) - (Es[2] - Es[0])
#
# File H:\taryn-phd\Cleaned\SingleQubitGates\SQGfunctions.py:142, in fluxonium_system(phi, Ej, Ec, El, n_op, phi_op, H_lc, H_i)
#     140 def fluxonium_system(phi,Ej,Ec,El,n_op,phi_op,H_lc,H_i):
#     141     H_sys = total_hamiltonian(phi,Ej,Ec,El,n_op,phi_op,H_lc,H_i)
# --> 142     evals, evecs = H_sys.eigenstates()
#     143     evals_sort = np.argsort(evals)
#     144     evals = evals[evals_sort]
#
# File C:\Programs\Anaconda3\lib\site-packages\qutip\qobj.py:1713, in Qobj.eigenstates(self, sparse, sort, eigvals, tol, maxiter, phase_fix)
#    1711     new_type = 'ket'
#    1712 ekets = np.empty((len(evecs),), dtype=object)
# -> 1713 ekets[:] = [Qobj(vec, dims=new_dims, type=new_type) for vec in evecs]
#    1714 norms = np.array([ket.norm() for ket in ekets])
#    1715 if phase_fix is None:
#
# File C:\Programs\Anaconda3\lib\site-packages\qutip\qobj.py:1713, in <listcomp>(.0)
#    1711     new_type = 'ket'
#    1712 ekets = np.empty((len(evecs),), dtype=object)
# -> 1713 ekets[:] = [Qobj(vec, dims=new_dims, type=new_type) for vec in evecs]
#    1714 norms = np.array([ket.norm() for ket in ekets])
#    1715 if phase_fix is None:
#
# File C:\Programs\Anaconda3\lib\site-packages\qutip\qobj.py:273, in Qobj.__init__(self, inpt, dims, shape, type, isherm, copy, fast, superrep, isunitary)
#     271 do_copy = copy
#     272 if not isinstance(inpt, fast_csr_matrix):
# --> 273     _tmp = sp.csr_matrix(inpt, dtype=complex, copy=do_copy)
#     274     _tmp.sort_indices()  # Make sure indices are sorted.
#     275     do_copy = 0
#
# File C:\Programs\Anaconda3\lib\site-packages\scipy\sparse\_compressed.py:84, in _cs_matrix.__init__(self, arg1, shape, dtype, copy)
#      81     except Exception as e:
#      82         raise ValueError("unrecognized {}_matrix constructor usage"
#      83                          "".format(self.format)) from e
# ---> 84     self._set_self(self.__class__(
#      85         self._coo_container(arg1, dtype=dtype)
#      86     ))
#      88 # Read matrix dimensions given, if any
#      89 if shape is not None:
#
# File C:\Programs\Anaconda3\lib\site-packages\scipy\sparse\_compressed.py:33, in _cs_matrix.__init__(self, arg1, shape, dtype, copy)
#      31         arg1 = arg1.copy()
#      32     else:
# ---> 33         arg1 = arg1.asformat(self.format)
#      34     self._set_self(arg1)
#      36 elif isinstance(arg1, tuple):
#
# File C:\Programs\Anaconda3\lib\site-packages\scipy\sparse\_base.py:376, in spmatrix.asformat(self, format, copy)
#     374 # Forward the copy kwarg, if it's accepted.
#     375 try:
# --> 376     return convert_method(copy=copy)
#     377 except TypeError:
#     378     return convert_method()
#
# File C:\Programs\Anaconda3\lib\site-packages\scipy\sparse\_coo.py:404, in coo_matrix.tocsr(self, copy)
#     401 indices = np.empty_like(col, dtype=idx_dtype)
#     402 data = np.empty_like(self.data, dtype=upcast(self.dtype))
# --> 404 coo_tocsr(M, N, self.nnz, row, col, self.data,
#     405           indptr, indices, data)
#     407 x = self._csr_container((data, indices, indptr), shape=self.shape)
#     408 if not self.has_canonical_format:
#
# KeyboardInterrupt:

# %% [markdown]
# # Export Data

# %%
data = {'FidelityCMA': fids,
        'ErrorCMA': errors,
        'LambdasCMA': lambdas,
        'EdsCMA': Eds}

df = pd.DataFrame(data)
df.to_csv('\filepath\filename.csv')
